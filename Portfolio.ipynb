# %% [markdown]
# <a href="https://colab.research.google.com/github/jcanty6/Fun-Side-Projects/blob/master/Portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %%
columns = []
var = "Year,Month,DayofMonth,DayOfWeek,DepTime,CRSDepTime,ArrTime,CRSArrTime,UniqueCarrier,FlightNum,TailNum,ActualElapsedTime,CRSElapsedTime,AirTime,ArrDelay,DepDelay,Origin,Dest,Distance,TaxiIn,TaxiOut,Cancelled,CancellationCode,Diverted,CarrierDelay,WeatherDelay,NASDelay,SecurityDelay,LateAircraftDelay"
for items in var.split(","):
    columns.append(items)
columns
# Out:
# ['Year',
#  'Month',
#  'DayofMonth',
#  'DayOfWeek',
#  'DepTime',
#  'CRSDepTime',
#  'ArrTime',
#  'CRSArrTime',
#  'UniqueCarrier',
#  'FlightNum',
#  'TailNum',
#  'ActualElapsedTime',
#  'CRSElapsedTime',
#  'AirTime',
#  'ArrDelay',
#  'DepDelay',
#  'Origin',
#  'Dest',
#  'Distance',
#  'TaxiIn',
#  'TaxiOut',
#  'Cancelled',
#  'CancellationCode',
#  'Diverted',
#  'CarrierDelay',
#  'WeatherDelay',
#  'NASDelay',
#  'SecurityDelay',
#  'LateAircraftDelay']

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/noahgift/porfolio/master/10kflightdata.csv")
df.columns = columns

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  ...  NASDelay  SecurityDelay  LateAircraftDelay
# 0  2008      2          21  ...       0.0            0.0               41.0
# 1  2008      1          19  ...       NaN            NaN                NaN
# 2  2008      1          25  ...       NaN            NaN                NaN
# 3  2008      2           8  ...       0.0            0.0               70.0
# 4  2008      1          20  ...       NaN            NaN                NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ## EDA

# %%
df.describe()
# Out:
#          Year        Month  ...  SecurityDelay  LateAircraftDelay
# count  9999.0  9999.000000  ...    2587.000000        2587.000000
# mean   2008.0     1.427043  ...       0.066100          22.481252
# std       0.0     0.494673  ...       1.120659          40.266743
# min    2008.0     1.000000  ...       0.000000           0.000000
# 25%    2008.0     1.000000  ...       0.000000           0.000000
# 50%    2008.0     1.000000  ...       0.000000           0.000000
# 75%    2008.0     2.000000  ...       0.000000          29.500000
# max    2008.0     2.000000  ...      37.000000         430.000000
#
# [8 rows x 24 columns]

# %%
import seaborn as sns
sns.lmplot(x="ArrTime", y = "CRSDepTime" , data = df)

# %% [markdown]
# ## Model

# %% [markdown]
# ## Conclusion
